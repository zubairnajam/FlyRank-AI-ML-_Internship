# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/zubairnajam/Week1/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#Lane: Refresh / Content Opportunity Scoring.
#I'm picking this because it maps to a decision a content team already has to make every week — which pages to review first — and because the starter dataset and pipeline (content_refresh_anonymized.csv, scripts/01–05) let me get a working baseline-to-model comparison running in week one instead of spending weeks just wrangling the warehouse. It also has the clearest "cost of being wrong" of the four lanes: a reviewer's time is finite, so a bad ranking wastes hours on pages that were never worth touching.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
#Decision: which content pages should a reviewer look at first out of a much larger inventory, given limited review capacity.
#Who acts on it: a content/SEO reviewer (or team lead assigning review queues) who has time to check maybe 20–50 pages a week, not thousands.
#Cost of a wrong call: false positives burn reviewer hours on pages that were never declining or never had recoverable demand — capacity that could've gone to a real opportunity. False negatives are worse in a different way: a genuinely declining, high-demand page sits unreviewed and keeps losing visibility. Neither error is catastrophic on its own, but at scale they compound into wasted review cycles and missed recoverable traffic.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
#These are the verified numbers from the guide's own committed outputs (outputs/model_results.json, outputs/model_report.md) on the 30,000-row starter slice, client-holdout validated:
#Baseline rule-based score: Precision@50 = 0.240 (about 12 of the top 50 flagged pages are true positives)
#Random forest model: Precision@50 = 0.740 (about 37 of 50) and ROC AUC = 0.750, vs. the baseline's 0.627
#That's roughly a 3x lift in top-of-queue precision from a learned model over the fixed rule — on a small slice, with proper client holdout, which is a reasonable signal this lane is worth the next 7 weeks.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
#What this work can say: observed associations between content signals (impressions, position, freshness, CTR) and later-labeled decline; a ranked, decision-support queue that a human reviewer still has to check; directional statements like "pages with X pattern were more often flagged as declining in this sample."
#What it can never say: that a refresh caused recovery (no experiment, no causal design here — just observational data); that any result generalizes beyond the 30,000-row starter slice or the specific warehouse snapshot; that it reflects Google's actual ranking algorithm; that AI-referral patterns mean anything about AI citations or AI search rankings. Every number is a decision aid, not a verdict.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
